# %% [markdown]
# **Tạo môi trường ảo:**
#
# Mở terminal hoặc command prompt và chạy lệnh sau:

# %%
python3 -m venv env

# %% [markdown]
# **Kích hoạt môi trường ảo**

# %%
# Trên Windows:
myenv\Scripts\activate
# Trên macOS và Linux:
source env/bin/activate

# %% [markdown]
# **Cài đặt các gói cần thiết**:

# %%
pip install package_name

# %% [markdown]
# **Lưu danh sách các gói đã cài đặt**

# %%
pip freeze > requirements.txt

# %% [markdown]
# **Hủy kích hoạt môi trường**

# %%
deactivate

# %% [markdown]
# **Khi tái tạo lại môi trường với file requirements.txt đã có**

# %%
pip install -r requirements.txt

# %% [markdown]
# **Một số lỗi có thể gặp**:
#
# Chưa cài đặt module venv, nếu chưa thì chạy dòng sau:

# %%
pip install virtualenv
sudo apt-get install python3-venv

# %% [markdown]
# **Xóa một môi trường đã tạo**
#
# Tìm xóa thư mục môi trường ảo

# %% [markdown]
# dự_án_của_bạn/
# │
# ├── venv/               # Thư mục môi trường ảo
# │   ├── bin/
# │   ├── lib/
# │   └── ...
# │
# ├── src/                # Thư mục chứa mã nguồn Python
# │   ├── main.py
# │   └── ...
# │
# ├── tests/              # Thư mục chứa các tệp kiểm thử
# │   ├── test_main.py
# │   └── ...
# │
# ├── requirements.txt    # Tệp liệt kê các gói cần thiết
# ├── README.md           # Tệp mô tả dự án
# └── .gitignore          # Tệp cấu hình Git
